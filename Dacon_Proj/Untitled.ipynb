# %%
import pandas as pd

# %%
train = pd.read_csv('data/train.csv')

# %%
train.T.head()
# Out:
#                   0                 1                 2                 3      \
# Time   2016-07-26 11:00  2016-07-26 12:00  2016-07-26 13:00  2016-07-26 14:00
# X692                NaN               NaN               NaN               NaN
# X1272               NaN               NaN               NaN               NaN
# X553                NaN               NaN               NaN               NaN
# X1299               NaN               NaN               NaN               NaN
#
#                   4                 5                 6                 7      \
# Time   2016-07-26 15:00  2016-07-26 16:00  2016-07-26 17:00  2016-07-26 18:00
# X692                NaN               NaN               NaN               NaN
# X1272               NaN               NaN               NaN               NaN
# X553                NaN               NaN               NaN               NaN
# X1299               NaN               NaN               NaN               NaN
#
# ...

# %%
train.head(24)
# Out:
#                 Time  X692  X1272  X553  X1299  X4  X598  X1003  X1010  X1216  \
# 0   2016-07-26 11:00   NaN    NaN   NaN    NaN NaN   NaN    NaN    NaN    NaN
# 1   2016-07-26 12:00   NaN    NaN   NaN    NaN NaN   NaN    NaN    NaN    NaN
# 2   2016-07-26 13:00   NaN    NaN   NaN    NaN NaN   NaN    NaN    NaN    NaN
# 3   2016-07-26 14:00   NaN    NaN   NaN    NaN NaN   NaN    NaN    NaN    NaN
# 4   2016-07-26 15:00   NaN    NaN   NaN    NaN NaN   NaN    NaN    NaN    NaN
# 5   2016-07-26 16:00   NaN    NaN   NaN    NaN NaN   NaN    NaN    NaN    NaN
# 6   2016-07-26 17:00   NaN    NaN   NaN    NaN NaN   NaN    NaN    NaN    NaN
# 7   2016-07-26 18:00   NaN    NaN   NaN    NaN NaN   NaN    NaN    NaN    NaN
# 8   2016-07-26 19:00   NaN    NaN   NaN    NaN NaN   NaN    NaN    NaN    NaN
# 9   2016-07-26 20:00   NaN    NaN   NaN    NaN NaN   NaN    NaN    NaN    NaN
# 10  2016-07-26 21:00   NaN    NaN   NaN    NaN NaN   NaN    NaN    NaN    NaN
# ...

# %%
stats = train.describe()
[i for i in range(1299) if stats.iloc[0][i] == 0]
# Out:
# [4, 286, 622, 756, 834, 915, 1024, 1241]

# %%
stats
# Out:
#               X692        X1272         X553        X1299   X4         X598  \
# count  3064.000000  3065.000000  3041.000000  3006.000000  0.0  3041.000000
# mean      0.371506     0.410571     0.519877     0.260363  NaN     0.268325
# std       0.190358     0.272845     0.236184     0.231955  NaN     0.149223
# min       0.049000     0.066000     0.053000     0.017000  NaN     0.034000
# 25%       0.271000     0.225000     0.416000     0.114000  NaN     0.162000
# 50%       0.329000     0.338000     0.485000     0.176500  NaN     0.228000
# 75%       0.430000     0.536000     0.581000     0.339000  NaN     0.346000
# max       4.104000     4.837000     6.232000     5.624000  NaN     2.718000
#
#              X1003        X1010        X1216        X1047  ...        X1164  \
# count  2937.000000  3048.000000  3064.000000  3062.000000  ...  3040.000000
# mean      0.378017     0.424614     0.302138     0.273101  ...     0.410577
# ...

# %%
no_data = ['X4','X622','X756','X834','X915','X1024','X1241']
train.drop(no_data, axis=1)
# Out:
#                    Time   X692  X1272   X553  X1299   X598  X1003  X1010  \
# 0      2016-07-26 11:00    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1      2016-07-26 12:00    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2      2016-07-26 13:00    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3      2016-07-26 14:00    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4      2016-07-26 15:00    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 5      2016-07-26 16:00    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 6      2016-07-26 17:00    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 7      2016-07-26 18:00    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 8      2016-07-26 19:00    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 9      2016-07-26 20:00    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 10     2016-07-26 21:00    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 11     2016-07-26 22:00    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ...
